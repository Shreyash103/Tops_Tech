# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Create a sample dataset
np.random.seed(42)  # For reproducibility
data = np.random.randint(20, 60, 100)  # 100 random integers between 20 and 60

# Create a Pandas DataFrame from the NumPy array
df = pd.DataFrame(data, columns=['age'])
df
# Out:
#     age
# 0    58
# 1    48
# 2    34
# 3    27
# 4    40
# ..  ...
# 95   28
# 96   27
# 97   31
# 98   53
# 99   52
#
# [100 rows x 1 columns]

# %%
# 1. Compute Mean, Median, Mode, Variance, and Standard Deviation
mean = np.mean(df['age'])
median = np.median(df['age'])
mode = stats.mode(df['age'])[0][0] 
variance = np.var(df['age'])
std_dev = np.std(df['age'])

# Print the computed values
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Mean: 38.79
# Median: 39.5
# Mode: 27
# Variance: 132.2059
# Standard Deviation: 11.49808244882598
# /var/folders/8w/1scy062n0tjfpqtvjsnmwmc40000gn/T/ipykernel_4572/3425025518.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(df['age'])[0][0]

# %%
# 2. Generate Histogram
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['age'], bins=15, kde=True, color='skyblue', edgecolor='black')
plt.title('Age Distribution - Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')

# 3. Generate Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(data=df, x='age', color='lightgreen')
plt.title('Age Distribution - Boxplot')
plt.xlabel('Age')

# Display both plots
plt.tight_layout()
plt.show()
